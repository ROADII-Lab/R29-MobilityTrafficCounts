# %%
import pandas as pd
import datetime

HayesDANA = pd.read_parquet(r'C:\Users\William.Chupp\OneDrive - DOT OST\Documents\ROADII-DATAPROGRAM\R29-MobilityCounts\TestData\HayesCountyTexas\DANA_Tool_Outputs_20240903\Process1_LinkLevelDataset\TX_Composite_Emissions.parquet')
for c in HayesDANA.columns: print(c)
# Out:
# index
# measurement_tstamp
# travel_time_all
# speed_all
# travel_time_pass
# speed_pass
# travel_time_truck
# npmrds_fill_method
# speed_truck
# year
# month
# day
# hour
# weekday
# dow
# peaking
# Unnamed: 0
# tmc
# road
# direction
# start_latitude
# start_longitude
# end_latitude
# end_longitude
# tmc_length
# road_order
# f_system
# faciltype
# thrulanes
# route_numb
# route_sign
# aadt
# aadt_singl
# aadt_combi
# nhs
# isprimary
# active_start_date
# active_end_date
# thrulanes_unidir
# aadt_unidir
# aadt_singl_unidir
# aadt_combi_unidir
# dir_num
# urban_rural
# state
# county
# COUNTY_ID
# repcty
# PCT_TYPE10
# PCT_TYPE25
# PCT_TYPE40
# PCT_TYPE50
# PCT_TYPE60
# PCT_NOISE_AUTO
# PCT_NOISE_MED_TRUCK
# PCT_NOISE_HVY_TRUCK
# PCT_NOISE_BUS
# PCT_NOISE_MC
# tier
# VOLUME_MODIFIER
# tier_volume
# dayid
# monthid
# hourid
# roadtypeid
# avgspeedbinid
# avgspeedbinid_pass
# avgspeedbinid_truck
# monthid3
# VMT
# MAADT
# 10_100
# 10_110
# 10_2
# 10_3
# 10_5
# 10_6
# 10_87
# 10_90
# ...

# %%
HayesDANA.columns
